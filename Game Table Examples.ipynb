# %% [markdown]
# We present the game tables for various game boards discussed 'A Computational Solution to the Game of Cycles' (Zonnefeld, Jannsen, and Kautz) and 'The Game of Cycles' (Alvarado et. al.).

# %%
#Figure 1 (Alvarado et. al.)
table = [[[2],[0],[0],[0],[0],[0],[4]],
         [[5],[3],[0],[0],[0],[0],[1]],
         [[0],[5],[6],[0],[0],[0],[2]],
         [[1],[0],[0],[5],[0],[0],[7]],
         [[4],[2],[3],[7],[8],[6],[0]],
         [[0],[0],[5],[0],[0],[9],[3]],
         [[0],[0],[0],[4],[5],[0],[8]],
         [[0],[0],[0],[0],[7],[5],[9]],
         [[0],[0],[0],[0],[0],[8],[6]]]

# %% [markdown]
# ![Su%20Figure%201.png](attachment:Su%20Figure%201.png)

# %%
#Figure 8 (Zonnefeld, Janssen, Kautz) and Theorem 3 (Alvarado et. al.)
table = [[[2],[5]],
         [[3],[1]],
         [[4],[2]],
         [[5],[3]],
         [[1],[4]]]

# %% [markdown]
# ![C5%20%28Su%20Theorem%203%29.png](attachment:C5%20%28Su%20Theorem%203%29.png)

# %%
#Figure 6 (Zonnefeld, Janssen, Kautz) and Figure 4 (Alvarado et. al.)
table = [[[4],[2],[0],[3]],
         [[0],[4],[3],[1]],
         [[1],[0],[4],[2]],
         [[3],[1],[2],[0]]]

# %% [markdown]
# ![K4.png](attachment:K4.png)

# %%
#Theorem 4 (Alvarado et. al.)
table = [[[4],[2],[7]],
         [[0],[3],[1]],
         [[0],[4],[2]],
         [[5],[1],[3]],
         [[6],[0],[4]],
         [[7],[0],[5]],
         [[1],[0],[6]]]

# %% [markdown]
# ![Odd%20Cycle%20w:%20Internal%20Chord.png](attachment:Odd%20Cycle%20w:%20Internal%20Chord.png)

# %%
#Theorem 4 (Alvarado et. al.)
table = [[[4],[2],[8]],
         [[0],[3],[1]],
         [[0],[4],[2]],
         [[5],[1],[3]],
         [[6],[0],[4]],
         [[7],[0],[5]],
         [[8],[0],[6]],
         [[1],[0],[7]]]

# %% [markdown]
# ![Even%20Cycle%20w:%20Internal%20Chord.png](attachment:Even%20Cycle%20w:%20Internal%20Chord.png)

# %%
#Theorem 5 (Alvarado et. al.)
table = [[[8],[2],[7]],
         [[0],[3],[1]],
         [[0],[4],[2]],
         [[0],[5],[3]],
         [[0],[6],[4]],
         [[0],[7],[5]],
         [[1],[8],[6]],
         [[7],[1],[0]]]

# %% [markdown]
# ![Odd%20cycle%20w:%20inner%20vertex.png](attachment:Odd%20cycle%20w:%20inner%20vertex.png)

# %%
#Theorem 5 (Alvarado et. al.)
table = [[[9],[2],[8]],
         [[0],[3],[1]],
         [[0],[4],[2]],
         [[0],[5],[3]],
         [[0],[6],[4]],
         [[0],[7],[5]],
         [[0],[8],[6]],
         [[1],[9],[7]],
         [[8],[1],[0]]]

# %% [markdown]
# ![Even%20cycle%20w:%20inner%20vertex.png](attachment:Even%20cycle%20w:%20inner%20vertex.png)

# %%
#Figure 11 (Alvarado et. al.)
table = [[[2],[0],[0],[5],[4]],
         [[5],[3],[0],[0],[1]],
         [[0],[5],[4],[0],[2]],
         [[0],[0],[5],[1],[3]],
         [[1],[2],[3],[4],[0]]]

# %% [markdown]
# ![Su%20Figure%2011.png](attachment:Su%20Figure%2011.png)

# %%
#Figure 12 (Alvarado et. al.)
table = [[[2],[5],[4]],
         [[3],[0],[1]],
         [[5],[4],[2]],
         [[0],[1],[3]],
         [[1],[3],[0]]]

# %% [markdown]
# ![Su%20Figure%2012.png](attachment:Su%20Figure%2012.png)

# %%
#Figure 13 (Alvarado et. al.)
table = [[[4], [2], [5], [0], [0], [0], [7]],
         [[0], [5], [0], [3], [0], [8], [1]],
         [[0], [0], [0], [6], [4], [2], [8]],
         [[7], [0], [1], [0], [6], [0], [3]],
         [[0], [1], [6], [2], [0], [0], [0]],
         [[0], [0], [4], [5], [3], [0], [0]],
         [[1], [0], [0], [0], [0], [0], [4]],
         [[0], [0], [0], [0], [0], [3], [2]]]

# %% [markdown]
# ![Su%20Figure%2013.png](attachment:Su%20Figure%2013.png)

# %%
#Figure 14 (Alvarado et. al.)
table = [[[2],[0],[0],[5]],
         [[6],[3],[0],[1]],
         [[0],[6],[0],[2]],
         [[0],[0],[5],[6]],
         [[1],[0],[6],[4]],
         [[5],[2],[4],[3]]]

# %% [markdown]
# ![Su%20Figure%2014.png](attachment:Su%20Figure%2014.png)

# %%
#Figure 15 (Alvarado et. al.)
table = [[[2],[6],[0],[0],[5]],
         [[5],[0],[0],[3],[1]],
         [[0],[0],[0],[6],[2]],
         [[0],[0],[5],[0],[6]],
         [[1],[2],[6],[0],[4]],
         [[0],[5],[4],[2],[3]]]

# %% [markdown]
# ![Su%20Figure%2015.png](attachment:Su%20Figure%2015.png)

# %%
#Figure 16 (Alvarado et. al.)
table = [[[4],[2],[3]],
         [[0],[4],[1]],
         [[1],[0],[4]],
         [[3],[1],[2]]]

# %% [markdown]
# ![Su%20Figure%2016.png](attachment:Su%20Figure%2016.png)

# %%
#Figure 22 (Alvarado et. al.)
table = [[[2],[0],[0],[7]],
         [[7],[3],[0],[1]],
         [[0],[6],[4],[2]],
         [[0],[0],[5],[3]],
         [[0],[0],[6],[4]],
         [[0],[7],[3],[5]],
         [[1],[2],[0],[6]]]

# %% [markdown]
# ![Su%20Figure%2022.png](attachment:Su%20Figure%2022.png)
